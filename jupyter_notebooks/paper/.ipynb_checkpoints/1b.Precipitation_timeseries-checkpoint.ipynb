# %% [markdown]
# # Precipitation timeseries
#
# This notebook calculates the global average precipitation for each year at different float precisions.

# %% [markdown]
# # 1. Process the raw data

# %%
import glob
import xarray as xr
import numpy as np
from tqdm import tqdm
import pandas as pd
import sys

def get_global_weights():
    
    # Get the latitude weights from a special location
    
    r1 = '/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/Fig1_10year_Williams/'
    f = r1 + 'speedyoneWILLIAMS_L2_52_RN_10y/model_output00001.nc'
    df = xr.open_dataset(f)
    
    temperature = df.temperature    
    return temperature.latitude




def average_over_space(x,weights,use_weights):
    
    print ('Calculating average over space')
    print(use_weights)
    print(weights)
    print(x.weighted(weights).mean(("longitude", "latitude")))
    print('--------------------')
    
    if use_weights:
        return x.weighted(weights).mean(("longitude", "latitude")) # Get the average global precipitation at each timestep.
    else:
        return x.mean(("longitude", "latitude"))



def process_nc_file(f,weights,use_weights,correct_latitude_values):
    

    #Open dataset
    ds = xr.open_dataset(f)
    
    #Reset the latitude
    ds = ds.assign_coords(latitude=(correct_latitude_values))
    #And covert longitude to long1
    ds = ds.assign_coords({"longitude": (((ds.longitude + 180) % 360) - 180)})
    
        
    #Get precipitations
    LSP = ds.large_scale_precipitation * (6*60*60) / 1000 #mm / 6h
    CVP = ds.convective_precipitation  * (6*60*60) / 1000 #mm / 6h              

    if LSP.shape != (365, 48, 96):
        return False #Exit function and don't use this one
 
    #Average over space
    LSP_global_av = average_over_space(LSP,weights,use_weights) #365 points
    CVP_global_av = average_over_space(CVP,weights,use_weights) #365 points
    precipitation = LSP_global_av + CVP_global_av 
    
    #Average over time
    global_annual_average_precip = float(precipitation.mean().values)
    display(LSP,LSP_global_av)
    ds.close()
    return global_annual_average_precip
    



def process_ensemble_members(m,use_weights):
    
        
    print ('--------------------------')
    print ('Processing ensemble ',m)
    
    # Get the global weights at full precision.
    correct_latitude_values = get_global_weights()
    weights = np.cos(np.deg2rad(correct_latitude_values))
    weights.name = "weights"
    
    
    #Get the different available precisions in this m-directory
    root= f'/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_{m}/'
    precision_directories = sorted(glob.glob(root+'*'))
    
    
    dfs = [] 
    for p in precision_directories:
        
        #Read the float precision from the filename
        precision = p.split('/')[-1].split('_')[2]
        rounding = p.split('/')[-1].split('_')[3]
        pid = precision+'_'+rounding
        print(pid,p)
    
        nc_files = sorted(glob.glob(p+'/**/*model_output*.nc',recursive=True))

        precip_m = []
        for n in tqdm(nc_files[1:2]):
            precip = process_nc_file(n,weights,use_weights,correct_latitude_values)
            if precip is not False:   #False if the shape isnt correct
                precip_m.append(precip)
            
        
        sys.exit()
        #Make it a pandas df an append to dfs
        data_dictionary = {'time': np.arange(len(precip_m)),
                           'precip': precip_m}
        df = pd.DataFrame(data_dictionary)
        df['precision'] = pid
        display(df)
        dfs.append(df)
        
        
    #Now do some IO
   
    df = pd.concat(dfs).reset_index(drop=True)
    
    if use_weights:
        uw = 'weighted'
    else:
        uw = 'unweighted'
    
    
    fname = f'data/{m}_precip_timeseries_{uw}.pkl'
    print('ALl iterations completed. Now saving to file:', fname)
    pd.to_pickle(df,fname)

# %%
process_ensemble_members('m5',use_weights=True)
#process_ensemble_members('m6',use_weights=True)
#process_ensemble_members('m7',use_weights=True)
#process_ensemble_members('m8',use_weights=True)
# Out:
# --------------------------
# Processing ensemble  m5
# 10_RN /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5
#   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating average over space
# True
# <xarray.DataArray 'weights' (latitude: 48)>
# array([0.04956284, 0.11356847, 0.17747902, 0.24073213, 0.30300897,
#        0.36403136, 0.42353629, 0.48127071, 0.53699054, 0.59046096,
#        0.64145695, 0.68976415, 0.7351796 , 0.77751257, 0.81658534,
#        0.85223388, 0.88430859, 0.91267484, 0.9372136 , 0.9578219 ,
#        0.97441328, 0.98691811, 0.99528392, 0.99947562, 0.99947562,
#        0.99528392, 0.98691811, 0.97441328, 0.9578219 , 0.9372136 ,
#        0.91267484, 0.88430859, 0.85223388, 0.81658534, 0.77751257,
#        0.7351796 , 0.68976415, 0.64145695, 0.59046096, 0.53699054,
#        0.48127071, 0.42353629, 0.36403136, 0.30300897, 0.24073213,
#        0.17747902, 0.11356847, 0.04956284])
# Coordinates:
#   * latitude  (latitude) float64 87.16 83.48 79.78 ... -79.78 -83.48 -87.16
# Attributes:
#     units:    degrees
# <xarray.DataArray 'large_scale_precipitation' (forecast_period: 365)>
# array([0.21209377, 0.22653271, 0.23149795, 0.22922629, 0.25395362,
#        0.24132894, 0.23592779, 0.22774501, 0.22036105, 0.21168761,
#        0.22739244, 0.25066934, 0.22844709, 0.2544655 , 0.24000213,
#        0.24074123, 0.22967194, 0.22337029, 0.2343748 , 0.21101736,
#        0.19298375, 0.18194859, 0.19246385, 0.20493919, 0.21547507,
#        0.23661007, 0.25342163, 0.26740442, 0.23581716, 0.247646  ,
#        0.21162607, 0.20392273, 0.23294016, 0.23118963, 0.24587469,
#        0.23897877, 0.2392663 , 0.22959297, 0.22800981, 0.21823869,
#        0.19924822, 0.20806571, 0.25177232, 0.26500997, 0.28190851,
#        0.24353069, 0.22632275, 0.22264944, 0.25142408, 0.27590428,
#        0.27560921, 0.25691696, 0.24997695, 0.25742421, 0.24994584,
#        0.22761503, 0.21761058, 0.24387982, 0.23369514, 0.21034163,
#        0.21180322, 0.21499825, 0.23771129, 0.2499612 , 0.23549316,
#        0.22486488, 0.22778663, 0.22013548, 0.20395414, 0.21787264,
#        0.21716251, 0.23738969, 0.2261229 , 0.2290242 , 0.23476946,
#        0.21639461, 0.18658768, 0.18587055, 0.18576487, 0.20729056,
#        0.23145264, 0.24157388, 0.25174113, 0.24903961, 0.23600464,
#        0.22534257, 0.22029444, 0.22027318, 0.24590813, 0.24205118,
#        0.25344619, 0.26818681, 0.24964081, 0.21569152, 0.19650965,
#        0.19514051, 0.20233454, 0.21509073, 0.20676095, 0.22907268,
# ...
#        0.19657055, 0.19408787, 0.21342037, 0.23102355, 0.26322077,
#        0.2374767 , 0.2240513 , 0.22001475, 0.22260766, 0.23331093,
#        0.22078684, 0.23910784, 0.26032524, 0.26213174, 0.26302078,
#        0.24982454, 0.23276713, 0.24897629, 0.23861393, 0.24220515,
#        0.2461253 , 0.24915745, 0.23829239, 0.25685695, 0.24773866,
#        0.24719019, 0.27173925, 0.27884843, 0.25980339, 0.26181009,
#        0.26403407, 0.2522505 , 0.24945321, 0.23746435, 0.22706797,
#        0.23721488, 0.25045677, 0.24678149, 0.25199804, 0.22308184,
#        0.21939883, 0.2420792 , 0.24361033, 0.2341573 , 0.23428242,
#        0.22501004, 0.23350662, 0.24664227, 0.26243037, 0.27195156,
#        0.2670083 , 0.2672987 , 0.25488187, 0.22372483, 0.21660523,
#        0.21031951, 0.21651027, 0.2233136 , 0.24683801, 0.25180601,
#        0.23467162, 0.22931266, 0.21917016, 0.20822292, 0.19711228,
#        0.20874449, 0.21162374, 0.21509544, 0.23620341, 0.24837822,
#        0.26265003, 0.24820854, 0.24773936, 0.24959564, 0.24190666,
#        0.20730148, 0.23017373, 0.24514755, 0.22642644, 0.22349911,
#        0.23842693, 0.25203583, 0.24744725, 0.23814753, 0.23754993,
#        0.2201664 , 0.22607242, 0.22010822, 0.22728323, 0.23160521,
#        0.23633966, 0.24717409, 0.23195317, 0.22378308, 0.20847698,
#        0.19657183, 0.20184913, 0.25272349, 0.2759394 , 0.27698848])
# Coordinates:
#   * forecast_period  (forecast_period) timedelta64[ns] 365 days ... 729 days
# --------------------
# Calculating average over space
# True
# <xarray.DataArray 'weights' (latitude: 48)>
# array([0.04956284, 0.11356847, 0.17747902, 0.24073213, 0.30300897,
#        0.36403136, 0.42353629, 0.48127071, 0.53699054, 0.59046096,
#        0.64145695, 0.68976415, 0.7351796 , 0.77751257, 0.81658534,
#        0.85223388, 0.88430859, 0.91267484, 0.9372136 , 0.9578219 ,
#        0.97441328, 0.98691811, 0.99528392, 0.99947562, 0.99947562,
#        0.99528392, 0.98691811, 0.97441328, 0.9578219 , 0.9372136 ,
#        0.91267484, 0.88430859, 0.85223388, 0.81658534, 0.77751257,
#        0.7351796 , 0.68976415, 0.64145695, 0.59046096, 0.53699054,
#        0.48127071, 0.42353629, 0.36403136, 0.30300897, 0.24073213,
#        0.17747902, 0.11356847, 0.04956284])
# Coordinates:
#   * latitude  (latitude) float64 87.16 83.48 79.78 ... -79.78 -83.48 -87.16
# Attributes:
#     units:    degrees
# <xarray.DataArray 'convective_precipitation' (forecast_period: 365)>
# array([0.51317699, 0.49204692, 0.51444846, 0.48557433, 0.49478144,
#        0.46853759, 0.4621686 , 0.51715095, 0.48916205, 0.49333269,
#        0.3993388 , 0.58876553, 0.51994523, 0.50120098, 0.51314556,
#        0.40764944, 0.43839086, 0.51024734, 0.42146062, 0.51931797,
#        0.49036843, 0.51498601, 0.52687428, 0.48804067, 0.49669432,
#        0.57074082, 0.49743508, 0.53839009, 0.57974272, 0.59047518,
#        0.52914337, 0.48348378, 0.44027578, 0.39181548, 0.45148961,
#        0.52306594, 0.59126319, 0.43052928, 0.51839258, 0.49272393,
#        0.44623896, 0.46852713, 0.39827316, 0.45220749, 0.6792514 ,
#        0.6020303 , 0.40939154, 0.50436651, 0.59490242, 0.52441634,
#        0.49696117, 0.41432359, 0.55758422, 0.43762337, 0.40910663,
#        0.38093872, 0.59017493, 0.4799216 , 0.4539011 , 0.52727726,
#        0.45639424, 0.48616228, 0.58800333, 0.50252404, 0.44660413,
#        0.52788649, 0.59590277, 0.47507617, 0.52056974, 0.57256408,
#        0.61787241, 0.61573012, 0.4310157 , 0.47467736, 0.67743653,
#        0.47346771, 0.59545434, 0.51105007, 0.51503767, 0.44281028,
#        0.57651721, 0.5267061 , 0.56983264, 0.61688551, 0.48688578,
#        0.537062  , 0.44585274, 0.45370999, 0.5637991 , 0.44175685,
#        0.48231375, 0.39322623, 0.49237026, 0.55093909, 0.42948557,
#        0.4275987 , 0.49160747, 0.56168102, 0.53052778, 0.43784214,
# ...
#        0.54344455, 0.48929007, 0.59291116, 0.55781678, 0.54233209,
#        0.53809322, 0.48727213, 0.55932237, 0.47669573, 0.5147671 ,
#        0.68127836, 0.50835215, 0.41056401, 0.43028966, 0.46643891,
#        0.4842782 , 0.52779976, 0.53791054, 0.60491906, 0.56774698,
#        0.58898242, 0.45162093, 0.42787411, 0.45904778, 0.5070966 ,
#        0.45029982, 0.48255569, 0.49393021, 0.42111248, 0.45834126,
#        0.43375376, 0.5540391 , 0.43246672, 0.554612  , 0.57590291,
#        0.46793941, 0.47441346, 0.43828324, 0.56916628, 0.37955133,
#        0.4260437 , 0.43437755, 0.58424221, 0.43135468, 0.48186714,
#        0.46728868, 0.50866123, 0.55854615, 0.46279601, 0.65457355,
#        0.62977277, 0.53896169, 0.54316147, 0.6372467 , 0.46814401,
#        0.58620762, 0.44255897, 0.41350539, 0.5154738 , 0.54504964,
#        0.55500513, 0.4494636 , 0.40066425, 0.49299208, 0.52888521,
#        0.49236785, 0.50361733, 0.44006354, 0.57405089, 0.55232888,
#        0.58246609, 0.47705905, 0.45305535, 0.5949162 , 0.52039551,
#        0.43766874, 0.50879487, 0.48840567, 0.46666198, 0.56399547,
#        0.56295907, 0.45120433, 0.43271176, 0.56358439, 0.60700398,
#        0.57634112, 0.46189592, 0.52871245, 0.53679699, 0.5820709 ,
#        0.54535177, 0.53369107, 0.60309436, 0.53722057, 0.49398449,
#        0.41008486, 0.53796562, 0.55945958, 0.5292241 , 0.42233052])
# Coordinates:
#   * forecast_period  (forecast_period) timedelta64[ns] 365 days ... 729 days
# --------------------
# <xarray.DataArray 'large_scale_precipitation' (forecast_period: 365, latitude: 48, longitude: 96)>
# array([[[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         ...,
#         [0.00000000e+00, 0.00000000e+00, 4.65288162e-03, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#        [[1.78472900e-01, 1.66607666e-01, 1.53836060e-01, ...,
#          1.92810059e-01, 1.96435547e-01, 1.60510254e-01],
#         [3.94477844e-02, 2.40188599e-02, 8.27579498e-03, ...,
#          7.07794189e-02, 6.11801147e-02, 5.02624512e-02],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          1.83643341e-02, 1.09691620e-02, 2.30069160e-03],
# ...
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [1.84750557e-04, 0.00000000e+00, 0.00000000e+00, ...,
#          2.13460922e-03, 1.55267715e-03, 9.05728340e-04]],
#
#        [[8.19854736e-02, 8.34686279e-02, 8.30566406e-02, ...,
#          7.56408691e-02, 7.90191650e-02, 8.12026978e-02],
#         [0.00000000e+00, 0.00000000e+00, 6.07681274e-04, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         ...,
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00]]])
# Coordinates:
#   * longitude        (longitude) float64 0.0 3.75 7.5 ... -11.25 -7.5 -3.75
#   * latitude         (latitude) float64 87.16 83.48 79.78 ... -83.48 -87.16
#   * forecast_period  (forecast_period) timedelta64[ns] 365 days ... 729 days
# <xarray.DataArray 'large_scale_precipitation' (forecast_period: 365)>
# array([0.21209377, 0.22653271, 0.23149795, 0.22922629, 0.25395362,
#        0.24132894, 0.23592779, 0.22774501, 0.22036105, 0.21168761,
#        0.22739244, 0.25066934, 0.22844709, 0.2544655 , 0.24000213,
#        0.24074123, 0.22967194, 0.22337029, 0.2343748 , 0.21101736,
#        0.19298375, 0.18194859, 0.19246385, 0.20493919, 0.21547507,
#        0.23661007, 0.25342163, 0.26740442, 0.23581716, 0.247646  ,
#        0.21162607, 0.20392273, 0.23294016, 0.23118963, 0.24587469,
#        0.23897877, 0.2392663 , 0.22959297, 0.22800981, 0.21823869,
#        0.19924822, 0.20806571, 0.25177232, 0.26500997, 0.28190851,
#        0.24353069, 0.22632275, 0.22264944, 0.25142408, 0.27590428,
#        0.27560921, 0.25691696, 0.24997695, 0.25742421, 0.24994584,
#        0.22761503, 0.21761058, 0.24387982, 0.23369514, 0.21034163,
#        0.21180322, 0.21499825, 0.23771129, 0.2499612 , 0.23549316,
#        0.22486488, 0.22778663, 0.22013548, 0.20395414, 0.21787264,
#        0.21716251, 0.23738969, 0.2261229 , 0.2290242 , 0.23476946,
#        0.21639461, 0.18658768, 0.18587055, 0.18576487, 0.20729056,
#        0.23145264, 0.24157388, 0.25174113, 0.24903961, 0.23600464,
#        0.22534257, 0.22029444, 0.22027318, 0.24590813, 0.24205118,
#        0.25344619, 0.26818681, 0.24964081, 0.21569152, 0.19650965,
#        0.19514051, 0.20233454, 0.21509073, 0.20676095, 0.22907268,
# ...
#        0.19657055, 0.19408787, 0.21342037, 0.23102355, 0.26322077,
#        0.2374767 , 0.2240513 , 0.22001475, 0.22260766, 0.23331093,
#        0.22078684, 0.23910784, 0.26032524, 0.26213174, 0.26302078,
#        0.24982454, 0.23276713, 0.24897629, 0.23861393, 0.24220515,
#        0.2461253 , 0.24915745, 0.23829239, 0.25685695, 0.24773866,
#        0.24719019, 0.27173925, 0.27884843, 0.25980339, 0.26181009,
#        0.26403407, 0.2522505 , 0.24945321, 0.23746435, 0.22706797,
#        0.23721488, 0.25045677, 0.24678149, 0.25199804, 0.22308184,
#        0.21939883, 0.2420792 , 0.24361033, 0.2341573 , 0.23428242,
#        0.22501004, 0.23350662, 0.24664227, 0.26243037, 0.27195156,
#        0.2670083 , 0.2672987 , 0.25488187, 0.22372483, 0.21660523,
#        0.21031951, 0.21651027, 0.2233136 , 0.24683801, 0.25180601,
#        0.23467162, 0.22931266, 0.21917016, 0.20822292, 0.19711228,
#        0.20874449, 0.21162374, 0.21509544, 0.23620341, 0.24837822,
#        0.26265003, 0.24820854, 0.24773936, 0.24959564, 0.24190666,
#        0.20730148, 0.23017373, 0.24514755, 0.22642644, 0.22349911,
#        0.23842693, 0.25203583, 0.24744725, 0.23814753, 0.23754993,
#        0.2201664 , 0.22607242, 0.22010822, 0.22728323, 0.23160521,
#        0.23633966, 0.24717409, 0.23195317, 0.22378308, 0.20847698,
#        0.19657183, 0.20184913, 0.25272349, 0.2759394 , 0.27698848])
# Coordinates:
#   * forecast_period  (forecast_period) timedelta64[ns] 365 days ... 729 days
# 100%|██████████| 1/1 [00:00<00:00,  3.10it/s]
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /home/k/kimpson/bin/conda/envs/workhorse/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3465: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# # 2...and now load and plot it

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
import numpy as np


def plot_timeseries(df):
    
    #Set up plot figure
    
    h,w = 20,20

    sns.set_theme(context='talk', 
                  style='ticks', 
                  palette='deep',
                  rc={'figure.figsize':(h,w)}
                  )

    fig, (ax1,ax2) = plt.subplots(nrows=2, ncols=1, sharex=True, figsize=(h,w))
    
    
    #Part A: TIMESERIES
    p = sns.lineplot(data=df, 
                     x="time", y='precip',
                     ax=ax1,
                     hue="precision",style="precision",markers=True)

# %%
precip_timeseries_data = sorted(glob.glob('data/m*_precip_timeseries_weighted.pkl'))

precip_dfs = []
for d in precip_timeseries_data:
    df = pd.read_pickle(d)
    display(df)
    plot_timeseries(df)
    precip_dfs.append(df)
# Out:
#      time    precip precision
# 0       0  0.722066     10_RN
# 1       1       NaN     10_RN
# 2       2       NaN     10_RN
# 3       3       NaN     10_RN
# 4       4       NaN     10_RN
# ..    ...       ...       ...
# 395    95  0.785034     52_RN
# 396    96  0.792712     52_RN
# 397    97  0.781742     52_RN
# 398    98  0.791121     52_RN
# 399    99  0.781562     52_RN
#
# [400 rows x 3 columns]
#      time    precip precision
# 0       0  0.727220     10_RN
# 1       1       NaN     10_RN
# 2       2       NaN     10_RN
# 3       3       NaN     10_RN
# 4       4       NaN     10_RN
# ..    ...       ...       ...
# 395    95  0.783368     52_RN
# 396    96  0.792315     52_RN
# 397    97  0.779770     52_RN
# 398    98  0.782678     52_RN
# 399    99  0.792042     52_RN
#
# [400 rows x 3 columns]
#      time    precip precision
# 0       0  0.724915     10_RN
# 1       1       NaN     10_RN
# 2       2       NaN     10_RN
# 3       3       NaN     10_RN
# 4       4       NaN     10_RN
# ..    ...       ...       ...
# 395    95  0.784487     52_RN
# 396    96  0.791750     52_RN
# 397    97  0.782829     52_RN
# 398    98  0.779598     52_RN
# 399    99  0.785876     52_RN
#
# [400 rows x 3 columns]
#      time    precip precision
# 0       0  0.724515     10_RN
# 1       1       NaN     10_RN
# 2       2       NaN     10_RN
# 3       3       NaN     10_RN
# 4       4       NaN     10_RN
# ..    ...       ...       ...
# 395    95  0.787389     52_RN
# 396    96  0.792672     52_RN
# 397    97  0.786949     52_RN
# 398    98  0.782290     52_RN
# 399    99  0.787921     52_RN
#
# [400 rows x 3 columns]

# %%
precip_dfs
# Out:
# ['data/m5_precip_timeseries_weighted.pkl',
#  'data/m6_precip_timeseries_weighted.pkl',
#  'data/m7_precip_timeseries_weighted.pkl',
#  'data/m8_precip_timeseries_weighted.pkl']

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
import numpy as np


def plot_timeseries(df):
    
    #Set up plot figure
    
    h,w = 20,20

    sns.set_theme(context='talk', 
                  style='ticks', 
                  palette='deep',
                  rc={'figure.figsize':(h,w)}
                  )

    fig, (ax1,ax2) = plt.subplots(nrows=2, ncols=1, sharex=True, figsize=(h,w))
    
    
    #Part A: TIMESERIES
    p = sns.lineplot(data=df, 
                     x="time", y='precip',
                     ax=ax1,
                     hue="precision",style="precision",markers=True)

# %%
plot_timeseries(df)

# %%
f8 = '/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m8/speedyone100yr_L2_52_RN_m8/model_output00055.nc'
f7 = '/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_52_RN_m7/model_output00055.nc'

# %%
import xarray as xr
df7 =  xr.open_dataset(f7)
df8 =  xr.open_dataset(f8)

# %%
def calc(ds):

    #Get precipitations
    LSP = ds.large_scale_precipitation * (6*60*60) / 1000 #mm / 6h
    CVP = ds.convective_precipitation  * (6*60*60) / 1000 #mm / 6h              

         
        
    #Average
    LSP_av = LSP.mean(("longitude", "latitude"))
    CVP_av = CVP.mean(("longitude", "latitude"))
    precipitation = LSP_av + CVP_av 
    
    return precipitation

# %%
p8 = calc(df8)
p7 = calc(df7)

# %%
p8.mean()
# Out:
# <xarray.DataArray ()>
# array(0.67245353)

# %%
p7.mean()
# Out:
# <xarray.DataArray ()>
# array(0.67528153)

# %%
p7
# Out:
# <xarray.DataArray (forecast_period: 365)>
# array([0.        , 0.64396705, 0.62377284, 0.71139291, 0.64117134,
#        0.73438115, 0.57861534, 0.7295237 , 0.68768495, 0.60493947,
#        0.61987204, 0.51783714, 0.5806324 , 0.57715273, 0.56141977,
#        0.58467261, 0.56598452, 0.63452142, 0.73590867, 0.58373477,
#        0.55012382, 0.60536432, 0.66676394, 0.52714262, 0.59628101,
#        0.60512604, 0.63233581, 0.66076122, 0.52743212, 0.54454419,
#        0.54058376, 0.51372199, 0.65814206, 0.64164389, 0.67467506,
#        0.66125535, 0.65326216, 0.55222329, 0.56942741, 0.59509293,
#        0.61809084, 0.5779053 , 0.66032054, 0.57362398, 0.6321388 ,
#        0.72236477, 0.67242137, 0.58758309, 0.57075698, 0.60319951,
#        0.61565115, 0.68654005, 0.53999618, 0.56022174, 0.60615625,
#        0.65139858, 0.65656072, 0.67732201, 0.6490188 , 0.65171094,
#        0.64127055, 0.63658664, 0.57971088, 0.54092306, 0.49089288,
#        0.5692779 , 0.60235768, 0.62752879, 0.61719511, 0.55417973,
#        0.58678593, 0.57784675, 0.59519304, 0.66257035, 0.51616556,
#        0.53203524, 0.60297804, 0.61806901, 0.641384  , 0.65873915,
#        0.66662598, 0.64454531, 0.54581427, 0.64275346, 0.58747973,
#        0.54288176, 0.61628644, 0.61390831, 0.64316206, 0.65819598,
#        0.62438623, 0.59248299, 0.56930039, 0.64582036, 0.61786097,
#        0.61192328, 0.7181671 , 0.63632786, 0.53844413, 0.61018218,
# ...
#        0.60683592, 0.59144881, 0.60127321, 0.61707313, 0.65197514,
#        0.58849876, 0.6022097 , 0.61934531, 0.58369495, 0.70080053,
#        0.59109044, 0.68990357, 0.64307872, 0.63549916, 0.58741836,
#        0.56780657, 0.57905469, 0.6494221 , 0.61615135, 0.63203601,
#        0.64501623, 0.5972054 , 0.58761324, 0.57999374, 0.58673755,
#        0.58476691, 0.55619975, 0.59746833, 0.6230533 , 0.66514147,
#        0.6442311 , 0.60682761, 0.58794567, 0.61863725, 0.5933272 ,
#        0.59630929, 0.56144436, 0.58497324, 0.55258712, 0.58899185,
#        0.56877321, 0.59479885, 0.5971371 , 0.50867214, 0.58576573,
#        0.6238802 , 0.60750067, 0.65624742, 0.66163804, 0.65944261,
#        0.64246326, 0.6521552 , 0.69901084, 0.60878877, 0.54134586,
#        0.52046876, 0.64484236, 0.56871846, 0.61457555, 0.65370427,
#        0.68296033, 0.52901534, 0.60858389, 0.68431479, 0.63831839,
#        0.63961441, 0.62706226, 0.58356469, 0.57090363, 0.52626501,
#        0.59282083, 0.63487244, 0.61610481, 0.64832813, 0.60767344,
#        0.57527974, 0.60806259, 0.60414397, 0.58014347, 0.64090597,
#        0.61779412, 0.57768803, 0.55371359, 0.61835508, 0.60053535,
#        0.54700855, 0.6375971 , 0.56610458, 0.60964691, 0.63283377,
#        0.60267405, 0.63587159, 0.55489011, 0.6420235 , 0.64258316,
#        0.62710045, 0.61487594, 0.64150112, 0.59858899, 0.53562105])
# Coordinates:
#   * forecast_period  (forecast_period) timedelta64[ns] 0 days ... 364 days

# %% [markdown]
# # What if we just load one member?

# %%
df6  = pd.read_pickle('m5_example.pkl')


def process_single_example(df):
    
    df_averaged = df.groupby([df.index//time_period, 'label','level','precision', 'title'],as_index=False).mean()
    
    
    df52 = df_averaged.query('precision == "52_RN"').copy()
    dfrest = df_averaged.query('precision != "52_RN"').copy()

    df52['merge_column'] = df52['X'].astype(int) #Create a column to merge on.  
    dfrest['merge_column'] = dfrest['X'].astype(int) #Create a column to merge on.  



    #merge
    df_join = pd.merge(dfrest,df52,how='left', on='merge_column', suffixes=(None, '_52RN'))
    df_join['MBE'] = df_join['temperature'] - df_join['temperature_52RN']
    df_join['MAE'] = abs(df_join['temperature'] - df_join['temperature_52RN'])
    
    display(df_join.groupby(by='precision').mean())

# %%
df5 = pd.read_pickle('m5_example.pkl')
process_single_example(df5)
# Out:
#            temperature        X  merge_column  temperature_52RN   X_52RN  \
# precision
# 10_RN       290.899987  18249.5       18249.5        290.944332  18249.5
# 10_SR       290.958596  18249.5       18249.5        290.944332  18249.5
# 23_RN       290.940689  18249.5       18249.5        290.944332  18249.5
#
#                 MBE       MAE
# precision
# 10_RN     -0.044345  0.051589
# 10_SR      0.014264  0.033596
# 23_RN     -0.003643  0.027036

# %%
df6 = pd.read_pickle('m6_example.pkl')
process_single_example(df6)
# Out:
#            temperature        X  merge_column  temperature_52RN   X_52RN  \
# precision
# 10_RN       290.901412  18249.5       18249.5         290.94025  18249.5
# 10_SR       290.963709  18249.5       18249.5         290.94025  18249.5
# 23_RN       290.941315  18249.5       18249.5         290.94025  18249.5
#
#                 MBE       MAE
# precision
# 10_RN     -0.038839  0.044088
# 10_SR      0.023459  0.034519
# 23_RN      0.001065  0.024896

# %%
df7 = pd.read_pickle('m7_example.pkl')
process_single_example(df7)
# Out:
#            temperature        X  merge_column  temperature_52RN   X_52RN  \
# precision
# 10_RN       290.901086  18249.5       18249.5         290.93587  18249.5
# 10_SR       290.966847  18249.5       18249.5         290.93587  18249.5
# 23_RN       290.939314  18249.5       18249.5         290.93587  18249.5
#
#                 MBE       MAE
# precision
# 10_RN     -0.034784  0.043336
# 10_SR      0.030978  0.040696
# 23_RN      0.003444  0.023897

# %%
process_single_example(df.query('ensemble == "m6"'))
# Out:
#            temperature        X  merge_column  temperature_52RN   X_52RN  \
# precision
# 10_RN       290.901412  18249.5       18249.5         290.94025  18249.5
# 10_SR       290.963709  18249.5       18249.5         290.94025  18249.5
# 23_RN       290.941315  18249.5       18249.5         290.94025  18249.5
#
#                 MBE       MAE
# precision
# 10_RN     -0.038839  0.044088
# 10_SR      0.023459  0.034519
# 23_RN      0.001065  0.024896
