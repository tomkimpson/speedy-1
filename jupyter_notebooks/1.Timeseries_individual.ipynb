# %%
import glob
import xarray as xr
import numpy as np
from tqdm import tqdm

#Functions

def get_global_weights():
    
     #Get the latitude weights from a special location
    r1 = '/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/Fig1_10year_Williams/'
    f = r1 + 'speedyoneWILLIAMS_L2_52_RN_10y/model_output00001.nc'
    df = xr.open_dataset(f)
    
    temp_file = df.temperature
    weights = np.cos(np.deg2rad(temp_file.latitude))
         
    weights.name = "weights"
    
    
    return weights, temp_file.latitude


import pandas as pd
def extract_file_info(d):
    
    #Mapping between levels
    level_dict = {'L1': 'El Nino Static SST. ablco2=6',
                  'L2': 'EC Earth SST. ablco2=6',
                  'L3': 'El Nino Static SST. ablco2=21',
                  'L4': 'EC Earth SST. ablco2=21'
                  }

    #Create some useful labels
    label = d.split('/')[-1]
    level = label.split('_')[1]
    prec = label.split('_')[2]
    rounding = label.split('_')[3]
    title = level_dict[level]
    
    keys = ['label', 'level', 'precision','title']
    values = [label,level,prec+'_'+rounding,title]
    dictionary = {keys[i]: values[i] for i in range(len(keys))}
    
    return dictionary




def surface_slice(y,weights):
    
 
    #Get values at surface
    y_surface =  y[:,0]   
    ygrid = y_surface.weighted(weights).mean(("longitude", "latitude")).data #average across every surface grid point


    return ygrid


def extract_file_data(df,columns,weights):
    
    
    data = [surface_slice(getattr(df,
                                  columns[k]),
                                   weights = weights) for k in range(len(columns))]
    
    
    dictionary = {columns[i]: data[i] for i in range(len(columns))}
    df_out = pd.DataFrame(dictionary)
    
    
    return df_out

    
    
def process_nc_file(fname,weights,directory,true_lat):    
    
        #Get data 
        df = xr.open_dataset(fname)
        
        
        #Reset the latitude
        df = df.assign_coords(latitude=(true_lat))
        

       
        #Get the data you want     
        columns_3d  = ['temperature']
        data3d = extract_file_data(df,columns_3d,weights)

                
        #Get meta information
        f_info = extract_file_info(directory)
        index = data3d.index
        df_info = pd.DataFrame(f_info,index=index)
      
        #Create pandas df and append
        df_meta = pd.concat([data3d,df_info,],axis=1) 
        
        return df_meta
    
    
def process_all_data(all_directories,weights,true_lat):

    
    #Empty arrays to hold data
    dfs = []
    for d in all_directories: #for every directory
        
        print ('directory',d)
        df_LI = [] # df of solution level i
        nc_files = sorted(glob.glob(d+'/**/*model_output*.nc',recursive=True))
        counter = 0
        #for n in tqdm(nc_files[0:100]): #for every model.nc file
        #for n in nc_files[0:100]:
        for n in tqdm(nc_files):
           # 
            df_meta = process_nc_file(n,weights,d,true_lat)
            print('File', counter , n,df_meta.shape)
            if df_meta.shape == (365,5):
                df_LI.append(df_meta)
                counter += 1
        
        df_LI = pd.concat(df_LI,ignore_index=True)
        df_LI['X'] = np.arange(len(df_LI))
        
        #Add append to bigger array
        dfs.append(df_LI)
            
    #Bring all together
    df = pd.concat(dfs)
    
    return df #.reset_index()



def process_node(node,fname):
    
    print ('--------------------------')
    print ('Processing', node, fname)

    #Parameters
    root= '/network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/'
    
    header_directories = glob.glob(root+node+'*')


    #Get the global weights
    weights,true_lat = get_global_weights()


    #Iterate over all directories
    df = process_all_data(header_directories,weights,true_lat)
    
    #save it
    pd.to_pickle(df,fname)
    
    return df

# %% [markdown]
# # Process all ensemble members

# %%
# #m5
node = 'paper/100year/tmp_m5/'
fname = 'm5_example.pkl'
df5 = process_node(node,fname)

#m6
node = 'paper/100year/tmp_m6/'
fname = 'm6_example.pkl'
df6 = process_node(node,fname)

#m7
node = 'paper/100year/tmp_m7/'
fname = 'm7_example.pkl'
df7 = process_node(node,fname)
# Out:
# --------------------------
# Processing paper/100year/tmp_m5/ m5_example.pkl
# directory /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5
# File 0 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00001.nc (365, 5)
# File 1 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00002.nc (365, 5)
# File 2 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00003.nc (365, 5)
# File 3 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00004.nc (365, 5)
# File 4 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00005.nc (365, 5)
# File 5 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00006.nc (365, 5)
# File 6 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00007.nc (365, 5)
# File 7 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00008.nc (365, 5)
# File 8 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00009.nc (365, 5)
# File 9 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00010.nc (365, 5)
# File 10 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00011.nc (365, 5)
# File 11 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00012.nc (365, 5)
# File 12 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00013.nc (365, 5)
# File 13 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00014.nc (365, 5)
# File 14 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00015.nc (365, 5)
# File 15 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00016.nc (365, 5)
# File 16 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00017.nc (365, 5)
# File 17 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00018.nc (365, 5)
# File 18 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00019.nc (365, 5)
# File 19 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00020.nc (365, 5)
# File 20 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00021.nc (365, 5)
# File 21 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00022.nc (365, 5)
# File 22 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00023.nc (365, 5)
# File 23 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00024.nc (365, 5)
# File 24 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00025.nc (365, 5)
# File 25 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00026.nc (365, 5)
# File 26 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00027.nc (365, 5)
# File 27 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00028.nc (365, 5)
# File 28 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00029.nc (365, 5)
# File 29 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00030.nc (365, 5)
# File 30 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00031.nc (365, 5)
# File 31 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00032.nc (365, 5)
# File 32 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00033.nc (365, 5)
# File 33 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00034.nc (365, 5)
# File 34 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00035.nc (365, 5)
# File 35 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00036.nc (365, 5)
# File 36 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00037.nc (365, 5)
# File 37 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00038.nc (365, 5)
# File 38 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00039.nc (365, 5)
# File 39 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00040.nc (365, 5)
# File 40 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00041.nc (365, 5)
# File 41 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00042.nc (365, 5)
# File 42 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00043.nc (365, 5)
# File 43 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00044.nc (365, 5)
# File 44 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00045.nc (365, 5)
# File 45 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00046.nc (365, 5)
# File 46 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00047.nc (365, 5)
# File 47 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00048.nc (365, 5)
# File 48 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00049.nc (365, 5)
# File 49 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00050.nc (365, 5)
# File 50 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00051.nc (365, 5)
# File 51 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00052.nc (365, 5)
# File 52 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00053.nc (365, 5)
# File 53 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00054.nc (365, 5)
# File 54 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00055.nc (365, 5)
# File 55 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00056.nc (365, 5)
# File 56 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00057.nc (365, 5)
# File 57 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00058.nc (365, 5)
# File 58 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00059.nc (365, 5)
# File 59 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00060.nc (365, 5)
# File 60 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00061.nc (365, 5)
# File 61 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00062.nc (365, 5)
# File 62 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00063.nc (365, 5)
# File 63 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00064.nc (365, 5)
# File 64 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00065.nc (365, 5)
# File 65 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00066.nc (365, 5)
# File 66 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00067.nc (365, 5)
# File 67 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00068.nc (365, 5)
# File 68 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00069.nc (365, 5)
# File 69 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00070.nc (365, 5)
# File 70 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00071.nc (365, 5)
# File 71 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00072.nc (365, 5)
# File 72 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00073.nc (365, 5)
# File 73 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00074.nc (365, 5)
# File 74 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00075.nc (365, 5)
# File 75 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00076.nc (365, 5)
# File 76 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00077.nc (365, 5)
# File 77 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00078.nc (365, 5)
# File 78 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00079.nc (365, 5)
# File 79 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00080.nc (365, 5)
# File 80 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00081.nc (365, 5)
# File 81 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00082.nc (365, 5)
# File 82 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00083.nc (365, 5)
# File 83 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00084.nc (365, 5)
# File 84 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00085.nc (365, 5)
# File 85 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00086.nc (365, 5)
# File 86 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00087.nc (365, 5)
# File 87 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00088.nc (365, 5)
# File 88 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00089.nc (365, 5)
# File 89 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00090.nc (365, 5)
# File 90 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00091.nc (365, 5)
# File 91 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00092.nc (365, 5)
# File 92 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00093.nc (365, 5)
# File 93 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00094.nc (365, 5)
# File 94 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00095.nc (365, 5)
# File 95 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00096.nc (365, 5)
# File 96 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00097.nc (365, 5)
# File 97 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00098.nc (365, 5)
# File 98 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00099.nc (365, 5)
# File 99 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00100.nc (365, 5)
# File 100 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_52_RN_m5/model_output00101.nc (1, 5)
# directory /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5
# File 0 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00001.nc (365, 5)
# File 1 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00002.nc (365, 5)
# File 2 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00003.nc (365, 5)
# File 3 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00004.nc (365, 5)
# File 4 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00005.nc (365, 5)
# File 5 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00006.nc (365, 5)
# File 6 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00007.nc (365, 5)
# File 7 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00008.nc (365, 5)
# File 8 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00009.nc (365, 5)
# File 9 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00010.nc (365, 5)
# File 10 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00011.nc (365, 5)
# File 11 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00012.nc (365, 5)
# File 12 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00013.nc (365, 5)
# File 13 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00014.nc (365, 5)
# File 14 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00015.nc (365, 5)
# File 15 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00016.nc (365, 5)
# File 16 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00017.nc (365, 5)
# File 17 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00018.nc (365, 5)
# File 18 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00019.nc (365, 5)
# File 19 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00020.nc (365, 5)
# File 20 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00021.nc (365, 5)
# File 21 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00022.nc (365, 5)
# File 22 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00023.nc (365, 5)
# File 23 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00024.nc (365, 5)
# File 24 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00025.nc (365, 5)
# File 25 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00026.nc (365, 5)
# File 26 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00027.nc (365, 5)
# File 27 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00028.nc (365, 5)
# File 28 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00029.nc (365, 5)
# File 29 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00030.nc (365, 5)
# File 30 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00031.nc (365, 5)
# File 31 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00032.nc (365, 5)
# File 32 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00033.nc (365, 5)
# File 33 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00034.nc (365, 5)
# File 34 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00035.nc (365, 5)
# File 35 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00036.nc (365, 5)
# File 36 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00037.nc (365, 5)
# File 37 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00038.nc (365, 5)
# File 38 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00039.nc (365, 5)
# File 39 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00040.nc (365, 5)
# File 40 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00041.nc (365, 5)
# File 41 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00042.nc (365, 5)
# File 42 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00043.nc (365, 5)
# File 43 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00044.nc (365, 5)
# File 44 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00045.nc (365, 5)
# File 45 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00046.nc (365, 5)
# File 46 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00047.nc (365, 5)
# File 47 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00048.nc (365, 5)
# File 48 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00049.nc (365, 5)
# File 49 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00050.nc (365, 5)
# File 50 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00051.nc (365, 5)
# File 51 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00052.nc (365, 5)
# File 52 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00053.nc (365, 5)
# File 53 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00054.nc (365, 5)
# File 54 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00055.nc (365, 5)
# File 55 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00056.nc (365, 5)
# File 56 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00057.nc (365, 5)
# File 57 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00058.nc (365, 5)
# File 58 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00059.nc (365, 5)
# File 59 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00060.nc (365, 5)
# File 60 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00061.nc (365, 5)
# File 61 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00062.nc (365, 5)
# File 62 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00063.nc (365, 5)
# File 63 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00064.nc (365, 5)
# File 64 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00065.nc (365, 5)
# File 65 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00066.nc (365, 5)
# File 66 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00067.nc (365, 5)
# File 67 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00068.nc (365, 5)
# File 68 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00069.nc (365, 5)
# File 69 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00070.nc (365, 5)
# File 70 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00071.nc (365, 5)
# File 71 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00072.nc (365, 5)
# File 72 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00073.nc (365, 5)
# File 73 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00074.nc (365, 5)
# File 74 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00075.nc (365, 5)
# File 75 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00076.nc (365, 5)
# File 76 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00077.nc (365, 5)
# File 77 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00078.nc (365, 5)
# File 78 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00079.nc (365, 5)
# File 79 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00080.nc (365, 5)
# File 80 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00081.nc (0, 5)
# File 80 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00082.nc (365, 5)
# File 81 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00083.nc (365, 5)
# File 82 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00084.nc (365, 5)
# File 83 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00085.nc (365, 5)
# File 84 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00086.nc (365, 5)
# File 85 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00087.nc (365, 5)
# File 86 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00088.nc (365, 5)
# File 87 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00089.nc (365, 5)
# File 88 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00090.nc (365, 5)
# File 89 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00091.nc (365, 5)
# File 90 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00092.nc (365, 5)
# File 91 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00093.nc (365, 5)
# File 92 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00094.nc (365, 5)
# File 93 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00095.nc (365, 5)
# File 94 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00096.nc (365, 5)
# File 95 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00097.nc (365, 5)
# File 96 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00098.nc (365, 5)
# File 97 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00099.nc (365, 5)
# File 98 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00100.nc (365, 5)
# File 99 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00101.nc (365, 5)
# File 100 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_23_RN_m5/model_output00102.nc (1, 5)
# directory /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5
# File 0 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00001.nc (365, 5)
# File 1 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00002.nc (365, 5)
# File 2 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00003.nc (365, 5)
# File 3 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00004.nc (365, 5)
# File 4 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00005.nc (365, 5)
# File 5 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00006.nc (365, 5)
# File 6 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00007.nc (365, 5)
# File 7 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00008.nc (365, 5)
# File 8 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00009.nc (365, 5)
# File 9 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00010.nc (365, 5)
# File 10 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00011.nc (365, 5)
# File 11 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00012.nc (365, 5)
# File 12 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00013.nc (365, 5)
# File 13 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00014.nc (365, 5)
# File 14 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00015.nc (365, 5)
# File 15 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00016.nc (365, 5)
# File 16 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00017.nc (365, 5)
# File 17 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00018.nc (365, 5)
# File 18 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00019.nc (365, 5)
# File 19 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00020.nc (365, 5)
# File 20 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00021.nc (365, 5)
# File 21 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00022.nc (365, 5)
# File 22 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00023.nc (365, 5)
# File 23 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00024.nc (365, 5)
# File 24 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00025.nc (365, 5)
# File 25 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00026.nc (365, 5)
# File 26 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00027.nc (365, 5)
# File 27 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00028.nc (365, 5)
# File 28 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00029.nc (365, 5)
# File 29 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00030.nc (365, 5)
# File 30 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00031.nc (365, 5)
# File 31 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00032.nc (365, 5)
# File 32 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00033.nc (365, 5)
# File 33 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00034.nc (365, 5)
# File 34 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00035.nc (365, 5)
# File 35 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00036.nc (365, 5)
# File 36 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00037.nc (365, 5)
# File 37 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00038.nc (365, 5)
# File 38 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00039.nc (365, 5)
# File 39 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00040.nc (365, 5)
# File 40 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00041.nc (365, 5)
# File 41 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00042.nc (365, 5)
# File 42 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00043.nc (365, 5)
# File 43 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00044.nc (365, 5)
# File 44 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00045.nc (365, 5)
# File 45 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00046.nc (365, 5)
# File 46 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00047.nc (365, 5)
# File 47 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00048.nc (365, 5)
# File 48 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00049.nc (365, 5)
# File 49 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00050.nc (365, 5)
# File 50 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00051.nc (365, 5)
# File 51 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00052.nc (365, 5)
# File 52 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00053.nc (365, 5)
# File 53 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00054.nc (365, 5)
# File 54 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00055.nc (365, 5)
# File 55 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00056.nc (365, 5)
# File 56 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00057.nc (365, 5)
# File 57 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00058.nc (365, 5)
# File 58 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00059.nc (365, 5)
# File 59 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00060.nc (365, 5)
# File 60 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00061.nc (365, 5)
# File 61 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00062.nc (365, 5)
# File 62 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00063.nc (365, 5)
# File 63 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00064.nc (365, 5)
# File 64 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00065.nc (365, 5)
# File 65 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00066.nc (365, 5)
# File 66 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00067.nc (365, 5)
# File 67 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00068.nc (365, 5)
# File 68 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00069.nc (365, 5)
# File 69 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00070.nc (365, 5)
# File 70 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00071.nc (365, 5)
# File 71 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00072.nc (365, 5)
# File 72 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00073.nc (365, 5)
# File 73 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00074.nc (365, 5)
# File 74 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00075.nc (365, 5)
# File 75 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00076.nc (0, 5)
# File 75 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00077.nc (365, 5)
# File 76 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00078.nc (365, 5)
# File 77 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00079.nc (365, 5)
# File 78 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00080.nc (365, 5)
# File 79 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00081.nc (365, 5)
# File 80 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00082.nc (365, 5)
# File 81 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00083.nc (365, 5)
# File 82 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00084.nc (365, 5)
# File 83 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00085.nc (365, 5)
# File 84 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00086.nc (365, 5)
# File 85 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00087.nc (365, 5)
# File 86 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00088.nc (365, 5)
# File 87 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00089.nc (365, 5)
# File 88 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00090.nc (365, 5)
# File 89 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00091.nc (365, 5)
# File 90 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00092.nc (365, 5)
# File 91 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00093.nc (365, 5)
# File 92 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00094.nc (365, 5)
# File 93 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00095.nc (365, 5)
# File 94 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00096.nc (365, 5)
# File 95 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00097.nc (365, 5)
# File 96 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00098.nc (365, 5)
# File 97 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00099.nc (365, 5)
# File 98 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00100.nc (365, 5)
# File 99 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00101.nc (365, 5)
# File 100 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_RN_m5/model_output00102.nc (1, 5)
# directory /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_SR_m5
# File 0 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_SR_m5/speedyone100yr_L2_10_SR_m5/model_output00001.nc (365, 5)
# File 1 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_SR_m5/speedyone100yr_L2_10_SR_m5/model_output00002.nc (365, 5)
# File 2 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_SR_m5/speedyone100yr_L2_10_SR_m5/model_output00003.nc (365, 5)
# File 3 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_SR_m5/speedyone100yr_L2_10_SR_m5/model_output00004.nc (365, 5)
# File 4 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_SR_m5/speedyone100yr_L2_10_SR_m5/model_output00005.nc (365, 5)
# File 5 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_SR_m5/speedyone100yr_L2_10_SR_m5/model_output00006.nc (365, 5)
# File 6 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_SR_m5/speedyone100yr_L2_10_SR_m5/model_output00007.nc (365, 5)
# File 7 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_SR_m5/speedyone100yr_L2_10_SR_m5/model_output00008.nc (365, 5)
# File 8 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_SR_m5/speedyone100yr_L2_10_SR_m5/model_output00009.nc (365, 5)
# File 9 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_SR_m5/speedyone100yr_L2_10_SR_m5/model_output00010.nc (365, 5)
# File 10 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_SR_m5/speedyone100yr_L2_10_SR_m5/model_output00011.nc (365, 5)
# File 11 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_SR_m5/speedyone100yr_L2_10_SR_m5/model_output00012.nc (0, 5)
# File 11 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_SR_m5/speedyone100yr_L2_10_SR_m5_rst2/model_output00001.nc (365, 5)
# File 12 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_SR_m5/speedyone100yr_L2_10_SR_m5_rst2/model_output00002.nc (365, 5)
# File 13 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m5/speedyone100yr_L2_10_SR_m5/speedyone100yr_L2_10_SR_m5_rst2/model_output00003.nc (365, 5)
# ...
# File 14 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst2/model_output00004.nc (365, 5)
# File 15 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst2/model_output00005.nc (365, 5)
# File 16 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst2/model_output00006.nc (365, 5)
# File 17 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst2/model_output00007.nc (365, 5)
# File 18 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst2/model_output00008.nc (365, 5)
# File 19 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst2/model_output00009.nc (365, 5)
# File 20 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst2/model_output00010.nc (365, 5)
# File 21 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst2/model_output00011.nc (365, 5)
# File 22 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst2/model_output00012.nc (0, 5)
# File 22 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst3/model_output00001.nc (365, 5)
# File 23 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst3/model_output00002.nc (365, 5)
# File 24 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst3/model_output00003.nc (365, 5)
# File 25 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst3/model_output00004.nc (365, 5)
# File 26 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst3/model_output00005.nc (365, 5)
# File 27 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst3/model_output00006.nc (365, 5)
# File 28 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst3/model_output00007.nc (365, 5)
# File 29 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst3/model_output00008.nc (365, 5)
# File 30 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst3/model_output00009.nc (365, 5)
# File 31 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst3/model_output00010.nc (365, 5)
# File 32 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst3/model_output00011.nc (365, 5)
# File 33 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst3/model_output00012.nc (365, 5)
# File 34 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst3/model_output00013.nc (365, 5)
# File 35 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst3/model_output00014.nc (365, 5)
# File 36 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst3/model_output00015.nc (365, 5)
# File 37 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst3/model_output00016.nc (365, 5)
# File 38 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst3/model_output00017.nc (365, 5)
# File 39 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst3/model_output00018.nc (365, 5)
# File 40 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst3/model_output00019.nc (365, 5)
# File 41 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst3/model_output00020.nc (0, 5)
# File 41 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00001.nc (365, 5)
# File 42 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00002.nc (365, 5)
# File 43 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00003.nc (365, 5)
# File 44 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00004.nc (365, 5)
# File 45 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00005.nc (365, 5)
# File 46 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00006.nc (365, 5)
# File 47 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00007.nc (365, 5)
# File 48 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00008.nc (365, 5)
# File 49 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00009.nc (365, 5)
# File 50 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00010.nc (365, 5)
# File 51 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00011.nc (365, 5)
# File 52 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00012.nc (365, 5)
# File 53 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00013.nc (365, 5)
# File 54 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00014.nc (365, 5)
# File 55 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00015.nc (365, 5)
# File 56 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00016.nc (365, 5)
# File 57 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00017.nc (365, 5)
# File 58 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00018.nc (365, 5)
# File 59 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00019.nc (365, 5)
# File 60 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00020.nc (365, 5)
# File 61 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00021.nc (365, 5)
# File 62 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00022.nc (365, 5)
# File 63 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00023.nc (365, 5)
# File 64 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00024.nc (365, 5)
# File 65 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00025.nc (365, 5)
# File 66 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00026.nc (365, 5)
# File 67 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00027.nc (365, 5)
# File 68 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00028.nc (365, 5)
# File 69 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00029.nc (365, 5)
# File 70 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00030.nc (365, 5)
# File 71 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00031.nc (365, 5)
# File 72 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00032.nc (365, 5)
# File 73 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00033.nc (365, 5)
# File 74 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00034.nc (365, 5)
# File 75 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00035.nc (365, 5)
# File 76 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00036.nc (365, 5)
# File 77 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00037.nc (365, 5)
# File 78 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00038.nc (365, 5)
# File 79 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00039.nc (365, 5)
# File 80 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00040.nc (365, 5)
# File 81 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00041.nc (365, 5)
# File 82 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00042.nc (365, 5)
# File 83 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00043.nc (365, 5)
# File 84 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00044.nc (365, 5)
# File 85 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00045.nc (365, 5)
# File 86 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00046.nc (365, 5)
# File 87 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00047.nc (365, 5)
# File 88 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00048.nc (365, 5)
# File 89 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00049.nc (365, 5)
# File 90 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00050.nc (365, 5)
# File 91 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00051.nc (365, 5)
# File 92 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00052.nc (365, 5)
# File 93 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00053.nc (365, 5)
# File 94 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00054.nc (365, 5)
# File 95 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00055.nc (365, 5)
# File 96 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00056.nc (365, 5)
# File 97 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00057.nc (365, 5)
# File 98 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00058.nc (365, 5)
# File 99 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00059.nc (365, 5)
# File 100 /network/group/aopp/predict/TIP016_PAXTON_RPSPEEDY/speedyone/paper/100year/tmp_m7/speedyone100yr_L2_10_SR_m7/speedyone100yr_L2_10_SR_m7_rst4/model_output00060.nc (1, 5)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
def calculate_residuals(df):
    
    
    #Get a ground truth that all others will be compared against. i.e. 52 RNe
    df_truth = df.query('precision == "52_RN" ')[['X', 'temperature']]
    df_truth['merge_column'] = df_truth['X'].astype(int) #Create a column to merge on.     #Note integer conversions are needed for join

    
    #Get the others
    df_rest = df.query('precision != "52_RN" ').reset_index(drop=True) #reset index to avoid SettingWithCopyWarning
    df_rest['merge_column'] = df_rest['X'].astype('int') 
    

    #Rejoin - maybe a more efficient way to do this?
    df_join = pd.merge(df_rest,df_truth,how='left',on='merge_column', suffixes=(None, 'truth'))
    
    #Get residual
    df_join['MBE'] = df_join['temperature'] - df_join['temperaturetruth']
    df_join['MAE'] = abs(df_join['temperature'] - df_join['temperaturetruth'])
    
    print ('Average:')
    display(df_join.groupby(by=["precision"]).mean()) 
    display(len(df_join))
    return df_join

def plot_timeseries(df,time_period,title,savefig):
    
    #Take an average over time_period number of days. Set time_period = 365 for yearly average
    df_averaged = df.groupby([df.index//time_period, 'label','level','precision', 'title'],as_index=False).mean()
    df_averaged['years'] =  df_averaged['X'] / 365 #Convert from days to years
    
    #Get the residuals of the averaged df
    df_residuals = calculate_residuals(df_averaged)
    
    #Setup plot configuration
    h,w = 20,20

    sns.set_theme(context='talk', 
                  style='ticks', 
                  palette='deep',
                  rc={'figure.figsize':(h,w)}
                  )

    fig, (ax1,ax2) = plt.subplots(nrows=2, ncols=1, sharex=True, figsize=(h,w))

   
    
    
    #Plot the timeseries
    p = sns.lineplot(data=df_averaged, x="years", y='temperature', hue="precision",ax=ax1,style='precision',markers=True)
    
    #Plot the residuals
    q = sns.lineplot(data=df_residuals, x="years", y='MBE', hue="precision",ax=ax2,style='precision',markers=False,legend=None)

    #Config
    plt.subplots_adjust(wspace=0.1, hspace=0)

    ax1.set_ylabel("Global Mean Surface Temperature (K)")
    ax2.set_ylabel("Mean Bias Error(K)")

    
    ax2.set_xlabel("Time (years)")
    ax2.axhline(0.0, c='0.5', linestyle='--')
    #ax2.set_yscale('log')
    
    ax1.set_ylim(288,292.5)
    ax1.set_title(None)
    
    
    if savefig is not None:
        plt.savefig(savefig,bbox_inches='tight', pad_inches=0, dpi=300)

    #Other config
    ax1.legend().set_title(None)

# %%
for m in ['m5_example.pkl']: #,'m6_example.pkl','m7_example.pkl']:
    dtmp = pd.read_pickle(m)
    display(dtmp)
    plot_timeseries(dtmp,time_period=365,title=m,savefig='figs/m5_timeseries.png')
# Out:
#        temperature                       label level precision  \
# 0       286.025455  speedyone100yr_L2_52_RN_m5    L2     52_RN
# 1       286.725405  speedyone100yr_L2_52_RN_m5    L2     52_RN
# 2       286.979427  speedyone100yr_L2_52_RN_m5    L2     52_RN
# 3       287.126005  speedyone100yr_L2_52_RN_m5    L2     52_RN
# 4       287.245411  speedyone100yr_L2_52_RN_m5    L2     52_RN
# ...            ...                         ...   ...       ...
# 36495   291.799462  speedyone100yr_L2_10_SR_m5    L2     10_SR
# 36496   291.755692  speedyone100yr_L2_10_SR_m5    L2     10_SR
# 36497   291.688527  speedyone100yr_L2_10_SR_m5    L2     10_SR
# 36498   291.728683  speedyone100yr_L2_10_SR_m5    L2     10_SR
# 36499   291.752892  speedyone100yr_L2_10_SR_m5    L2     10_SR
#
#                         title      X
# 0      EC Earth SST. ablco2=6      0
# 1      EC Earth SST. ablco2=6      1
# 2      EC Earth SST. ablco2=6      2
# 3      EC Earth SST. ablco2=6      3
# 4      EC Earth SST. ablco2=6      4
# ...                       ...    ...
# 36495  EC Earth SST. ablco2=6  36495
# 36496  EC Earth SST. ablco2=6  36496
# 36497  EC Earth SST. ablco2=6  36497
# 36498  EC Earth SST. ablco2=6  36498
# 36499  EC Earth SST. ablco2=6  36499
#
# [146000 rows x 6 columns]
# Average:
#            temperature        X     years  merge_column   Xtruth  \
# precision
# 10_RN       290.899987  18249.5  49.99863       18249.5  18249.5
# 10_SR       290.958596  18249.5  49.99863       18249.5  18249.5
# 23_RN       290.940689  18249.5  49.99863       18249.5  18249.5
#
#            temperaturetruth       MBE       MAE
# precision
# 10_RN            290.944332 -0.044345  0.051589
# 10_SR            290.944332  0.014264  0.033596
# 23_RN            290.944332 -0.003643  0.027036
# 300

# %%
plot_timeseries(df,time_period=365)
# Out:
# Average:
#            temperature        X  years  merge_column   Xtruth  \
# precision
# 10_RN       290.901433  18250.0   50.0       18250.0  18250.0
# 10_SR       290.963730  18250.0   50.0       18250.0  18250.0
# 23_RN       290.941337  18250.0   50.0       18250.0  18250.0
#
#            temperaturetruth       MBE       MAE
# precision
# 10_RN            290.940274 -0.038841  0.126078
# 10_SR            290.940274  0.023456  0.135560
# 23_RN            290.940274  0.001063  0.120855
# 109503

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def plot_config(ax1,ax2,save):
    

    #Config
    plt.subplots_adjust(wspace=0.1, hspace=0)

    ax1.set_ylabel("Gloabl Mean Surface Temperature (K)")#, fontsize = 20)
    ax2.set_ylabel("Absolute Error (K)")#, fontsize = 20)


    ax2.set_xlabel("Time (years)")#, fontsize = 20)
    ax2.axhline(0.0, c='0.5', linestyle='--')
    

   # ax1.set_xlim(0,400)
    ax1.set_ylim(288,292.5)

    #Other config
    ax1.legend().set_title(None)
    
    if save:
        plt.savefig('figs/Fig1_Williams.png', dpi=300, bbox_inches='tight')


    
    
def get_relative_error_df(df):
    
    
    #Get a ground truth that all others will be compared against
    df_truth = df.query('precision == "52_RN" ')[['X', 'temperature']]
    df_truth['merge_column'] = df_truth['X'].astype(int)
    
    #Get the others
    df_rest = df.query('precision != "52_RN" ').reset_index(drop=True) #rest index to avoid SettingWithCopyWarning
    df_rest['merge_column'] = df_rest['X'].astype('int') 
    
    #Note integer conversions are needed for join

    #Rejoin - maybe a more efficient way to do this?
    df_join = pd.merge(df_rest,df_truth,how='left',on='merge_column', suffixes=(None, 'truth'))
    
    
    #Get the absolute error
    #df_join['error']  = df_join['temperature'] - df_join['temperaturetruth']
    df_join['error']  = abs(df_join['temperature'] - df_join['temperaturetruth'])/df_join['temperaturetruth']

    
    return df_join
    
def plot_error_timeseries(df1,df2,save_it):
    
    #Setup plot env
    h,w = 20,20

    sns.set_theme(context='talk', 
                  style='ticks', 
                  palette='deep',
                  rc={'figure.figsize':(h,w)}
                  )

    

    
    fig, (ax1,ax2) = plt.subplots(nrows=2, ncols=1, sharex=True, figsize=(h,w))
    
    df1['years'] = df1.X/365
    
    
    #Plot the df directly
    p = sns.lineplot(data=df1, x="years", y='temperature', hue="precision",ax=ax1,style='precision',markers=True)


    #Calculate the relative_error df and plot
    df_error = get_relative_error_df(df1)
    #df_error['years'] = df2.X #/365

    df_error['years'] = df_error['X']/365
    
    decadal_window = 1 #take an average over N years
    df_error_decadal = df_error.groupby([df_error.years//decadal_window, 'label','level','precision', 'title'],as_index=False).mean()
    p = sns.lineplot(data=df_error_decadal, x="years", y='error', hue="precision",ax=ax2,style='precision',markers=True,legend=None)


    plot_config(ax1,ax2,save_it)

# %%
save_it = True #Do you want to save the Fig?
plot_error_timeseries(df_annual_mean,df_decadal_mean,save_it)

# %%
df_decadal_mean['years'] = df_decadal_mean.X/365

# %%
df_error = get_relative_error_df(df_annual_mean)
